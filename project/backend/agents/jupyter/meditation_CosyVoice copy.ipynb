# %%
import sys

sys.path.append("/root/autodl-tmp/I-AM/CosyVoice")
sys.path.append("/root/autodl-tmp/I-AM/CosyVoice/third_party/Matcha-TTS")

# %%
sleep_texts = ["亲爱的朋友，请找一个舒适的地方躺下或坐下，闭上眼睛[breath]，开始我们的宁静之旅。",
"首先，深深地，吸一口气[breath]，感受空气缓缓进入你的鼻腔，充满你的肺部。",
"然后，慢慢地，呼出[breath]，感受所有的紧张和压力[quick_breath]随着呼气离开你的身体",
"再来一次，深深地，吸气[breath]，慢慢地，呼气[breath]。让每一次呼吸[quick_breath]都带你进入更深层的放松状态。",
"现在，让我们从脚趾开始，慢慢地[breath]扫描你的身体。感受你的脚趾，它们是否感到沉重，或轻松。让它们<strong>完全放松</strong>。",
"接着，是你的脚踝[breath]、小腿[breath]、膝盖[breath], 让每一块肌肉都放松下来。",
"继续向上，感受你的大腿[breath]、臀部[breath]、腹部[breath]，让它们都沉浸在舒适和放松中。",
"然后是胸部[breath]、肩膀[breath]、手臂[breath]，直到你的指尖。",
"最后，感受你的脖子[breath]、脸部[breath]，让所有的紧张都消失。",
"现在，想象你正躺在一片柔软的草地上，周围是宁静的夜晚。",
"你可以听到，微风轻轻拂过树叶的声音。感受到草地上的露珠，轻轻触碰你的皮肤。",
"抬头看，夜空中繁星点点，月亮温柔地照耀着你。感受这份宁静和安详。让它们充满你的整个身体。"
]
sleep_texts_silence_durations = [3000, 4000, 3000, 4000, 5000, 5000, 5000, 5000, 6000, 4000, 4000, 6000]



love_texts = [
    "我深深地相信[breath]，完美的爱情正在向我走来。每一天，我都在成为<strong>更好的自己</strong>，这让我离理想的爱情更近一步。",
    "我的心灵充满爱与温暖[breath]，我准备好迎接那个与我灵魂共鸣的人[sigh]。",
    "我知道我值得被真诚地爱着[breath]。宇宙已经为我安排好了<strong>最适合的伴侣</strong>，在最恰当的时机，我们终将相遇。",
    "我对未来的爱情充满信心[breath]，我的心扉敞开，准备接纳那个对的人[quick_breath]。",
    "我正在吸引一段<strong>健康、稳定、充满爱</strong>的关系[breath]。我的伴侣会欣赏我的全部，包容我的不完美，支持我的梦想[sigh]。",
    "我们之间的爱情将建立在相互理解、尊重和信任的基础上[breath]。",
    "每一天，我都能感受到自己在爱的能量中成长[breath]。我懂得爱自己，也知道如何去爱别人[quick_breath]。",
    "我的心中充满感激[breath]，感谢生命中所有的相遇与离别[sigh]，它们都在为我准备<strong>最好的爱情</strong>。",
    "我的理想伴侣正在靠近[breath]。我们会有共同的价值观，能够彼此理解，共同成长[quick_breath]。",
    "我们的关系将充满欢笑、温暖和支持。我们会一起创造美好的回忆，共同面对生活的挑战。",
    "我相信真爱的力量[breath]。我知道，当两个人真心相爱时，<strong>没有什么困难是无法克服的</strong>。",
    "我和我的伴侣将互相扶持[breath]，共同进步，让彼此成为更好的人[quick_breath]。",
    "我的爱情将是稳定而持久的[breath]。我们会互相尊重对方的个性和空间，同时保持亲密的连接[sigh]。",
    "我们的感情会随着时间的推移越来越深厚，越来越稳固[breath]。",
    "我正在散发着爱的能量[breath]，这种能量会吸引同样充满爱的人[quick_breath]。我的心灵是开放的，我的灵魂是自由的。",
    "我准备好与命中注定的那个人相遇[breath]，开启一段<strong>美好的感情旅程</strong>。",
    "我知道等待是值得的[breath]。在遇见对的人之前，我会好好地爱自己，充实自己，让自己成为一个更完整的人[sigh]。",
    "当爱情来临时[breath]，我已经准备好给予和接受<strong>最真挚的爱</strong>。",
    "我的爱情将是平等和互惠的[breath]。我们会互相关心，互相照顾，共同承担生活的责任[quick_breath]。",
    "我们的感情将建立在真诚的沟通和深刻的理解之上[breath]。",
    "我相信我们的爱情将经得起时间的考验[breath]。我们会一起经历人生的起起落落，分享彼此的喜怒哀乐[sigh]。",
    "我们的感情会像美酒一样，越陈越香[sigh]。",
    "此刻，我的心中充满期待和喜悦。我知道，美好的爱情正在路上，我所期待的那个人也正在向我走来[breath]。",
    "我们终将相遇[breath]，共创属于我们的<strong>幸福故事</strong>。",
    "我对爱情充满信心，也对自己充满信心[quick_breath]。我知道我值得拥有最好的爱情，而这份爱情一定会在最适合的时候降临[breath]。",
    "我的心中充满感激[breath]，感谢生命给予我遇见真爱的机会[sigh]。",
    "每一天，我都在用积极的心态迎接爱情[breath]。我知道，只要保持开放和真诚的心态，<strong>真爱终将会找到我</strong>。",
    "我期待着与那个对的人相遇[breath]，开启人生<strong>最美好的篇章</strong>。"
]
love_texts_silence_durations = [1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500, 1500]

# %%
prompt_speech_female1 = "/root/autodl-tmp/I-AM/project/backend/agents/prompts/vocals/female1_[12sec].wav"
prompt_speech_female2 ="/root/autodl-tmp/I-AM/project/backend/agents/prompts/vocals/female2_[16sec].wav"
prompt_speech_male1 = "/root/autodl-tmp/I-AM/project/backend/agents/prompts/vocals/male1_[12sec].wav"
prompt_speech_male2 = "/root/autodl-tmp/I-AM/project/backend/agents/prompts/vocals/male2_[16sec].wav"


prompt_text_female1_12sec = "我不为过往感到懊悔，也不为明天感到焦虑，我珍惜着此时此刻的完整和真实。"
prompt_text_female2_16sec = "你好，我是雅丽丝，这是古老传承的显化冥想，你可以运用这波冥想，来帮助自己吸引显化，吸引你的梦想称为现实。"
prompt_text_male1_12sec = "深深地吸气，缓缓地呼气，感受这具身体是否有疲劳，或者沉重的感觉。"
prompt_text_male2_16sec = "现在你可以熄灭灯光，将自己调整到最舒服的平躺姿势，让我带着你，通过今天的睡前放松，进入沉睡的梦想。"

background_music_01 = "/root/autodl-tmp/I-AM/project/backend/agents/prompts/background_music/bmusic_01.wav"
background_music_02 = "/root/autodl-tmp/I-AM/project/backend/agents/prompts/background_music/bmusic_02.wav"
background_music_03 = "/root/autodl-tmp/I-AM/project/backend/agents/prompts/background_music/bmusic_03.wav"

# %%
from cosyvoice.cli.cosyvoice import CosyVoice, CosyVoice2
from cosyvoice.utils.file_utils import load_wav
import torchaudio
cosyvoice = CosyVoice2('/root/autodl-fs/cosyvoice/pretrained_models/CosyVoice2-0.5B', load_jit=True, load_onnx=False, load_trt=False)


def tts_generate(text, prompt_text, prompt_speech_16k):
    for output in cosyvoice.inference_zero_shot(
        text,
        prompt_text,
        prompt_speech_16k,
        speed=1.0,
        stream=False
        ):
        return output

# %%
prompt_speech_16k = load_wav(prompt_speech_female2, 16000)

output = cosyvoice.inference_zero_shot(sleep_texts[0], prompt_text_female2_16sec, prompt_speech_16k)

# for i, text in enumerate(sleep_texts):
#     audio = tts_generate(text, prompt_text_female2_16sec, prompt_speech_16k)
#     torchaudio.save(
#         f'output/temp/audio_{i}.wav',
#         audio['tts_speech'],
#         cosyvoice.sample_rate
#     )

# %%
for au in output:
    print(au)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-01-10 17:00:41,239 INFO synthesis text 亲爱的朋友,请找一个舒适的地方躺下或坐下,闭上眼睛[breath],开始我们的宁静之旅。
# 2025-01-10 17:00:50,609 INFO yield speech len 11.0, rtf 0.8519037203355269
# 100%|██████████| 1/1 [00:11<00:00, 11.03s/it]
# {'tts_speech': tensor([[ 6.9621e-05,  8.3149e-06,  7.0321e-05,  ..., -6.1278e-07,
#          -1.6032e-05,  5.6354e-08]])}

# %%
import glob
import os
import re
from pydub import AudioSegment


def natural_sort_key(s):
    """用于实现自然排序的键函数"""
    result = []
    # 使用正则表达式分割字符串，保留数字
    parts = re.split('([0-9]+)', s)
    
    for text in parts:
        if text.isdigit():
            # 如果是数字，转换为整数
            result.append(int(text))
        else:
            # 如果是文本，转换为小写
            result.append(text.lower())
    
    return result

def combine_wav_files_with_pause_and_music(base_path, output_path, pause_durations, background_music_path, music_extension_duration=15000, crossfade_duration=100, fade_out_duration=5000):
    """
    连接多个 WAV 文件，并在之间添加停顿，同时添加背景音乐
    
    参数:
    base_path: 输入文件的基础路径
    output_path: 输出文件路径
    pause_durations: 每个段落之间的停顿时长列表(毫秒)
    background_music_path: 背景音乐文件路径
    music_extension_duration: 背景音乐在主音频结束后继续播放的时长(毫秒)
    crossfade_duration: 交叉淡入淡出的持续时间(毫秒)
    fade_out_duration: 背景音乐的渐出时长(毫秒)
    """
    wav_files = glob.glob(os.path.join(base_path, "*.wav"))
    wav_files.sort(key=natural_sort_key)

    for wav_file in wav_files:
        if not os.path.exists(wav_file):
            print(f"文件 {wav_file} 不存在")
            return
    
    print(f"找到以下文件: ")
    for wav_file in wav_files:
        print(wav_file)
    
    # 加载5秒静音
    combined = AudioSegment.silent(duration=5000)
    
    # 依次添加其他音频文件
    for i, wav_file in enumerate(wav_files):
        # 创建静音片段
        pause = AudioSegment.silent(duration=pause_durations[i])
        
        # 加载并添加下一个音频文件
        next_segment = AudioSegment.from_wav(wav_file)
        combined = combined.append(next_segment, crossfade=crossfade_duration)

        # 添加停顿
        combined = combined + pause
    
    # 添加额外的静音以延长背景音乐
    combined = combined + AudioSegment.silent(duration=music_extension_duration)
    
    # 加载背景音乐
    background_music = AudioSegment.from_file(background_music_path)
    
    # 调整背景音乐音量
    background_music = background_music - 15  # 减少音量，单位为dB
    
    # 截断或循环背景音乐以匹配合并音频的长度
    if len(background_music) < len(combined):
        background_music = background_music * ((len(combined) // len(background_music)) + 1)
    background_music = background_music[:len(combined)]
    
    # 添加渐入和渐出效果
    background_music = background_music.fade_in(fade_in_duration).fade_out(fade_out_duration)
    
    # 叠加背景音乐
    combined_with_music = combined.overlay(background_music)
    
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    # 导出合并后的文件
    combined_with_music.export(output_path, format="wav")
    print(f"已合并所有音频并添加背景音乐到：{output_path}")

# 使用示例
base_path = "output/tts/sleep/female2"
output_path = "output/tts/sleep/female2_combined_with_bmusic_03.wav"
pause_durations = love_texts_silence_durations
background_music_path = "/root/autodl-tmp/I-AM/project/backend/agents/prompts/background_music/bmusic_03.wav"
music_extension_duration = 30000  # 背景音乐延长30秒
fade_in_duration = 3000
fade_out_duration = 10000  # 渐出时长10秒

combine_wav_files_with_pause_and_music(
    base_path,
    output_path,
    pause_durations,
    background_music_path,
    music_extension_duration,
    fade_out_duration=fade_out_duration
)
